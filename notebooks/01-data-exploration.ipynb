# %%
import pandas as pd

# %%
df = pd.read_json('../data/wikihop/dev.json')
df.set_index('id')
# Out:
#                                                    annotations  \
# id
# WH_dev_0     [[follows, single], [follows, multiple], [foll...
# WH_dev_1     [[follows, multiple], [follows, single], [foll...
# WH_dev_2     [[not_follow, ], [not_follow, ], [likely, sing...
# WH_dev_3     [[likely, multiple], [not_follow, ], [not_foll...
# WH_dev_4     [[follows, single], [follows, single], [follow...
# WH_dev_5     [[follows, single], [follows, multiple], [not_...
# WH_dev_6     [[follows, multiple], [follows, multiple], [li...
# WH_dev_7     [[follows, single], [follows, multiple], [foll...
# WH_dev_8     [[likely, single], [follows, single], [likely,...
# WH_dev_9     [[follows, multiple], [follows, multiple], [fo...
# WH_dev_10    [[likely, single], [likely, single], [likely, ...
# WH_dev_11    [[follows, single], [follows, single], [follow...
# WH_dev_12    [[follows, multiple], [follows, single], [foll...
# WH_dev_13    [[follows, single], [follows, single], [likely...
# ...

# %%
df.head()
# Out:
#                                                    annotations  \
# id
# WH_dev_0     [[follows, single], [follows, multiple], [foll...
# WH_dev_1     [[follows, multiple], [follows, single], [foll...
# WH_dev_2     [[not_follow, ], [not_follow, ], [likely, sing...
# WH_dev_3     [[likely, multiple], [not_follow, ], [not_foll...
# WH_dev_4     [[follows, single], [follows, single], [follow...
# WH_dev_5     [[follows, single], [follows, multiple], [not_...
# WH_dev_6     [[follows, multiple], [follows, multiple], [li...
# WH_dev_7     [[follows, single], [follows, multiple], [foll...
# WH_dev_8     [[likely, single], [follows, single], [likely,...
# WH_dev_9     [[follows, multiple], [follows, multiple], [fo...
# WH_dev_10    [[likely, single], [likely, single], [likely, ...
# WH_dev_11    [[follows, single], [follows, single], [follow...
# WH_dev_12    [[follows, multiple], [follows, single], [foll...
# WH_dev_13    [[follows, single], [follows, single], [likely...
# ...
